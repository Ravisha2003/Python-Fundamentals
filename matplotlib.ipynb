# %%
#MATPLOTLIB

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([0,20],[0,6])

# %%
plt.plot([0,20],[0,6])
plt.show()

# %%
plt.scatter([0,20],[0,6])

# %%
plt.plot([0,20],[0,6],[0,10],[0,15])

# %%
plt.scatter([0,20,2],[0,6,4])

# %%
plt.plot([0,20,2],[0,6,4])

# %%
x=[0,20,2]
y=[0,6,2]
plt.plot(x,y)

# %%
plt.plot(x,y, 'bo')

# %%
plt.plot(x,y, 'r+')

# %%
plt.plot(x,y, 'r_')

# %%
plt.plot(x,y, 'g*')

# %%
plt.plot(x,y,color="blue",linewidth=5)

# %%
plt.plot(x,y,color="pink")

# %%
x=[0,20,2,7]
y=[0,10,4,5]
plt.plot(x,y,"y",linewidth=4)

# %%
x=[0,20,2,7]
y=[0,10,4,5]
plt.plot(x,y,"y",linewidth=4)
plt.title("RATE vs PRICE")
plt.xlabel("RATE")
plt.ylabel("PRICE")
plt.show()

# %%
from matplotlib import style
style.use("ggplot")
x=[0,20,2,7]
y=[0,10,4,5]
plt.plot(x,y,"y",linewidth=4)
plt.legend()
plt.title("RATE vs PRICE")
plt.xlabel("RATE")
plt.ylabel("PRICE")
plt.show()
# Out:
# C:\Users\ravis\AppData\Local\Temp\ipykernel_22032\2275805880.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from matplotlib import style
style.use("ggplot")
x1=[0,20,2,7]
y1=[0,10,4,5]
x2=[7,4,6,2]
y2=[9,7,12,6]
plt.plot(x1,y1,"y",linewidth=4,label="sales")
plt.plot(x2,y2,"r",linewidth=4,label="price")
plt.legend()
plt.title("LINE GRAPH")
plt.xlabel("RATE")
plt.ylabel("PRICE")
plt.show()

# %%
from matplotlib import style
style.use("ggplot")
x1=[0,20,2,7]
y1=[0,10,4,5]
x2=[7,4,6,2]
y2=[9,7,12,6]
plt.plot(x1,y1,"y",linewidth=4,label="sales")
plt.plot(x2,y2,"r",linewidth=4,label="price")
plt.legend()
plt.title("SALES vs PRICE")
plt.xlabel("RATE")
plt.ylabel("PRICE")
plt.show()

# %%
import numpy as np

# %%
x=np.array([1,2,6,8])
x
# Out:
# array([1, 2, 6, 8])

# %%
y=np.array([3,8,1,10])
y
# Out:
# array([ 3,  8,  1, 10])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,"o")

# %%
plt.plot(x,y,marker="o")

# %%
plt.plot(x,y,marker="v")

# %%
plt.plot(x,y,marker=".")

# %%
plt.plot(x,y,marker=",")

# %%
plt.plot(x,y,marker="^")

# %%
plt.plot(x,y,marker="<")

# %%
plt.plot(x,y,marker=">")

# %%
plt.plot(x,y,marker="3")

# %%
plt.plot(x,y,marker="h")

# %%
plt.plot(x,y,marker="P")

# %%
plt.plot(x,y,marker="D")

# %%
plt.plot(x,y,marker="o",ms=20)

# %%
plt.plot(x,y,marker="o",ms=50)

# %%
plt.plot(x,y,marker="o",ms=20,markeredgecolor="b")

# %%
plt.plot(x,y,marker="o",ms=20,markeredgecolor="b",markerfacecolor="g")

# %%
plt.plot(x,y,marker="o",ms=20,markeredgecolor="r",markerfacecolor="y",linestyle="dotted")

# %%
plt.plot(x,y,marker="o",ms=20,markeredgecolor="r",markerfacecolor="y",linestyle="dashed")

# %%
plt.plot(x,y,marker="o",ms=20,markeredgecolor="r",markerfacecolor="y",linestyle="dashed")
plt.grid(True)
plt.show()

# %%
plt.plot(x,y,marker="o",ms=20,markeredgecolor="r",markerfacecolor="y",linestyle="dashed")
plt.grid(True,color="r")
plt.show()

# %%
plt.plot(x,y,marker="o",ms=20,markeredgecolor="r",markerfacecolor="y",linestyle="dashed")
plt.grid(True,color="r",linewidth=4,axis="y")
plt.show()

# %%
x=np.array([2,4,6,8])
y=np.array([10,45,67,12])
plt.subplot(2,1,1)
plt.plot(x,y)

# %%
x=np.array([2,4,6,8])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)

# %%
x=np.array([2,4,6,8])
y=np.array([10,45,67,12])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([2,4,6,8])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
#TYPES OF GRAPHS

# %%
import matplotlib.pyplot as plt
from matplotlib import style
plt.bar([1,3,5,7,9],[5,2,7,6,8], label='Females')
plt.bar([2,4,6,8,1],[7,3,5,4,9], label='Males', color = 'g')
plt.bar([0,2,1,9,7],[8,7,6,4,5], label='others', color = 'blue')
plt.legend()
plt.xlabel('Ages')
plt.ylabel('Heights')
plt.title('info')
plt.show()

# %%
pop_ages=[12,14,15,17,2,14,15,21,23,25,85,42,1,6,7,9,50,51,54,58,57,56,52,51]
bins=[0,5,10,15,20,25,30,35,40,45]
plt.hist(pop_ages,bins,histtype='bar',rwidth=.2)
plt.xlabel('Ages')
plt.ylabel('Heights')
plt.title('info')
plt.show()

# %%
days=[1,2,3,4,5,6]
sleeping=[2,5,4,8,6,7]
eating=[5,6,7,9,1,4]
working=[7,8,5,1,4,9]
playing=[6,4,8,2,1,3]
plt.plot([],[],color='m', label='sleeping',linewidth=5)
plt.plot([],[],color='c', label='eating',linewidth=5)
plt.plot([],[],color='r', label='working',linewidth=5)
plt.plot([],[],color='k', label='playing',linewidth=5)
plt.stackplot(days,sleeping,eating,working,playing,colors=['m','c','r','k'])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()
plt.show()

# %%
slices=[7,2,2,13]
activities=['sleeping','eating','working','playing']
cols=['m','c','r','lime']
plt.pie(slices,labels=activities, colors=cols,startangle=90,shadow=True,explode=(0,0.1,0,0),autopct='%1.1f%%')
plt.title('pie chart')
plt.legend()
plt.show()
